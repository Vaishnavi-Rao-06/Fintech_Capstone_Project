# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/vaishnavi/Downloads/Fintech_Capstone_Project/data/raw/01_fund_master.csv")

# %%
print(data.shape)
# Out:
# (40, 15)

# %%
print(data.dtypes)
# Out:
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object

# %%
data.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %%
print(data.columns.tolist())
# Out:
# ['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category', 'plan', 'launch_date', 'benchmark', 'expense_ratio_pct', 'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager', 'risk_category', 'sebi_category_code']

# %%
data['launch_date'] = pd.to_datetime(data['launch_date'], format='mixed', dayfirst=True)

# %%
print(data['launch_date'].dtype)
# Out:
# datetime64[ns]

# %%
data['launch_date'].head()
# Out:
# 0   2006-02-14
# 1   2013-01-01
# 2   2009-09-09
# 3   2013-01-01
# 4   2000-12-30
# Name: launch_date, dtype: datetime64[ns]

# %%
print(data.isnull().sum())
# Out:
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64

# %%
invalid_expense = data[(data['expense_ratio_pct'] < 0.1) | (data['expense_ratio_pct'] > 2.5)]
print(f"Invalid expense ratio rows: {len(invalid_expense)}")
# Out:
# Invalid expense ratio rows: 0

# %%
if len(invalid_expense) == 0:
    print("valid")
# Out:
# valid

# %%
invalid_sip = data[data['min_sip_amount'] <= 0]
invalid_lumpsum = data[data['min_lumpsum_amount'] <= 0]

# %%
print(f"Invalid SIP amount rows: {len(invalid_sip)}")
print(f"Invalid lumpsum amount rows: {len(invalid_lumpsum)}")
# Out:
# Invalid SIP amount rows: 0
# Invalid lumpsum amount rows: 0

# %%
print("Categories:", data['category'].unique())
# Out:
# Categories: ['Equity' 'Debt']

# %%
print("Risk categories:", data['risk_category'].unique())
# Out:
# Risk categories: ['Moderate' 'Very High' 'Low' 'High' 'Moderately High']

# %%
before = len(data)
data = data.drop_duplicates(subset=['amfi_code'])
after = len(data)
print(f"Duplicates removed: {before - after}")
print(f"Remaining rows: {after}")
# Out:
# Duplicates removed: 0
# Remaining rows: 40

# %%
data.to_csv("C:/Users/vaishnavi/Downloads/Fintech_Capstone_Project/data/processed/clean_fund_master.csv", index=False)
print("Saved")
print(data.shape)
# Out:
# Saved
# (40, 15)
