# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/vaishnavi/Downloads/Fintech_Capstone_Project/data/raw/08_investor_transactions.csv")

# %%
print(data.shape)
# Out:
# (32778, 13)

# %%
print(data.dtypes)
# Out:
# investor_id            object
# transaction_date       object
# amfi_code               int64
# transaction_type       object
# amount_inr              int64
# state                  object
# city                   object
# city_tier              object
# age_group              object
# gender                 object
# annual_income_lakh    float64
# payment_mode           object
# kyc_status             object
# dtype: object

# %%
data.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
print(data.columns.tolist())
# Out:
# ['investor_id', 'transaction_date', 'amfi_code', 'transaction_type', 'amount_inr', 'state', 'city', 'city_tier', 'age_group', 'gender', 'annual_income_lakh', 'payment_mode', 'kyc_status']

# %%
print(data['transaction_type'].unique())
# Out:
# ['SIP' 'Redemption' 'Lumpsum']

# %%
print(data['transaction_type'].value_counts())
# Out:
# transaction_type
# SIP           19716
# Lumpsum        8095
# Redemption     4967
# Name: count, dtype: int64

# %%
data['transaction_date'] = pd.to_datetime(data['transaction_date'], format='mixed',dayfirst=True)

# %%
print(data['transaction_date'].dtype)
# Out:
# datetime64[ns]

# %%
data['transaction_date'].head()
# Out:
# 0   2024-01-01
# 1   2024-01-01
# 2   2024-01-01
# 3   2024-01-01
# 4   2024-01-01
# Name: transaction_date, dtype: datetime64[ns]

# %%
invalid_amt = data[data['amount_inr'] <=0]
print(f"Invalid amount rows: {len(invalid_amt)}")
# Out:
# Invalid amount rows: 0

# %%
data = data[data['amount_inr']>0]
print(f"Remaining rows:{len(data)}")
# Out:
# Remaining rows:32778

# %%
print(data['kyc_status'].unique())
# Out:
# ['Verified' 'Pending']

# %%
print(data['kyc_status'].value_counts())
# Out:
# kyc_status
# Verified    30146
# Pending      2632
# Name: count, dtype: int64

# %%
print(data.shape)
# Out:
# (32778, 13)

# %%
print(data.isnull().sum())
# Out:
# investor_id           0
# transaction_date      0
# amfi_code             0
# transaction_type      0
# amount_inr            0
# state                 0
# city                  0
# city_tier             0
# age_group             0
# gender                0
# annual_income_lakh    0
# payment_mode          0
# kyc_status            0
# dtype: int64

# %%
df.to_csv(
