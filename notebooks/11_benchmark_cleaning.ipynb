# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/vaishnavi/Downloads/Fintech_Capstone_Project/data/raw/10_benchmark_indices.csv")

# %%
print(data.shape)
# Out:
# (8050, 3)

# %%
print(data.dtypes)
# Out:
# date            object
# index_name      object
# close_value    float64
# dtype: object

# %%
data.head()
# Out:
#          date index_name  close_value
# 0  2022-01-03    NIFTY50     17492.79
# 1  2022-01-04    NIFTY50     17689.64
# 2  2022-01-05    NIFTY50     17835.05
# 3  2022-01-06    NIFTY50     17878.51
# 4  2022-01-07    NIFTY50     17759.15

# %%
print(data.columns.tolist())
# Out:
# ['date', 'index_name', 'close_value']

# %%
data['date'] = pd.to_datetime(data['date'], format='mixed', dayfirst=True)

# %%
print(data['date'].dtype)
# Out:
# datetime64[ns]

# %%
data['date'].head()
# Out:
# 0   2022-01-03
# 1   2022-01-04
# 2   2022-01-05
# 3   2022-01-06
# 4   2022-01-07
# Name: date, dtype: datetime64[ns]

# %%
print(data.isnull().sum())
# Out:
# date           0
# index_name     0
# close_value    0
# dtype: int64

# %%
print(f"Unique indices: {data['index_name'].nunique()}")
# Out:
# Unique indices: 7

# %%
print(data['index_name'].unique())
# Out:
# ['NIFTY50' 'NIFTY100' 'NIFTY_MIDCAP150' 'BSE_SMALLCAP' 'NIFTY500'
#  'CRISIL_LIQUID' 'CRISIL_GILT']

# %%
invalid = data[data['close_value'] <= 0]
print(f"Invalid close value rows: {len(invalid)}")
# Out:
# Invalid close value rows: 0

# %%
if len(invalid) == 0:
    print("valid")
# Out:
# valid

# %%
print(f"Date range: {data['date'].min()} to {data['date'].max()}")
# Out:
# Date range: 2022-01-03 00:00:00 to 2026-05-29 00:00:00

# %%
print(f"Total rows: {len(data)}")
# Out:
# Total rows: 8050

# %%
print(f"Unique dates: {data['date'].nunique()}")
# Out:
# Unique dates: 1150

# %%
data.to_csv("C:/Users/vaishnavi/Downloads/Fintech_Capstone_Project/data/processed/clean_benchmark_indices.csv", index=False)
print("Saved")
print(data.shape)
# Out:
# Saved
# (8050, 3)
