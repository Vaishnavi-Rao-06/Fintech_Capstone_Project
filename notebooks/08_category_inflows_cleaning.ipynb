# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/vaishnavi/Downloads/Fintech_Capstone_Project/data/raw/05_category_inflows.csv")

# %%
print(data.shape)
# Out:
# (144, 3)

# %%
print(data.dtypes)
# Out:
# month                object
# category             object
# net_inflow_crore    float64
# dtype: object

# %%
data.head()
# Out:
#      month         category  net_inflow_crore
# 0  2024-04        Large Cap            2413.0
# 1  2024-04          Mid Cap            3897.0
# 2  2024-04        Small Cap            3533.0
# 3  2024-04        Flexi Cap            4947.0
# 4  2024-04  Large & Mid Cap            4214.0

# %%
print(data.columns.tolist())
# Out:
# ['month', 'category', 'net_inflow_crore']

# %%
data['month'] = pd.to_datetime(data['month'], format='mixed', dayfirst=True)

# %%
print(data['month'].dtype)
# Out:
# datetime64[ns]

# %%
data['month'].head()
# Out:
# 0   2024-04-01
# 1   2024-04-01
# 2   2024-04-01
# 3   2024-04-01
# 4   2024-04-01
# Name: month, dtype: datetime64[ns]

# %%
print(f"Unique categories: {data['category'].nunique()}")
# Out:
# Unique categories: 12

# %%
print(data['category'].unique())
# Out:
# ['Large Cap' 'Mid Cap' 'Small Cap' 'Flexi Cap' 'Large & Mid Cap' 'ELSS'
#  'Value/Contra' 'Sectoral/Thematic' 'Liquid' 'Short Duration' 'Gilt'
#  'Hybrid']

# %%
print(data.isnull().sum())
# Out:
# month               0
# category            0
# net_inflow_crore    0
# dtype: int64

# %%
print(f" Min net inflow: {data['net_inflow_crore'].min()}")
print(f" Max net inflow: {data['net_inflow_crore'].max()}")
print(f" Negative inflow rows: {len(data[data['net_inflow_crore'] <0])}")
# Out:
#  Min net inflow: 437.0
#  Max net inflow: 41952.0
#  Negative inflow rows: 0

# %%
data.to_csv("C:/Users/vaishnavi/Downloads/Fintech_Capstone_Project/data/processed/clean_category_inflows.csv", index=False)
print("Saved")
print(data.shape)
# Out:
# Saved
# (144, 3)
