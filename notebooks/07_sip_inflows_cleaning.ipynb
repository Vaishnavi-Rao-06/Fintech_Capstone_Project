# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/Users/vaishnavi/Downloads/Fintech_Capstone_Project/data/raw/04_monthly_sip_inflows.csv")

# %%
print(data.shape)
# Out:
# (48, 6)

# %%
print(data.dtypes)
# Out:
# month                         object
# sip_inflow_crore               int64
# active_sip_accounts_crore    float64
# new_sip_accounts_lakh        float64
# sip_aum_lakh_crore           float64
# yoy_growth_pct               float64
# dtype: object

# %%
data.head()
# Out:
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN

# %%
print(data.columns.tolist())
# Out:
# ['month', 'sip_inflow_crore', 'active_sip_accounts_crore', 'new_sip_accounts_lakh', 'sip_aum_lakh_crore', 'yoy_growth_pct']

# %%
data['month'] = pd.to_datetime(data['month'], format='mixed', dayfirst=True)

# %%
print(data['month'].dtype)
# Out:
# datetime64[ns]

# %%
data['month'].head()
# Out:
# 0   2022-01-01
# 1   2022-02-01
# 2   2022-03-01
# 3   2022-04-01
# 4   2022-05-01
# Name: month, dtype: datetime64[ns]

# %%
invalid_sip = data[data['sip_inflow_crore'] <= 0]
print(f"Invalid SIP inflow rows: {len(invalid_sip)}")
# Out:
# Invalid SIP inflow rows: 0

# %%
if len(invalid_sip) > 0:
    print(invalid_sip)
else:
    print("valid")
# Out:
# valid

# %%
invalid_accounts = data[data['active_sip_accounts_crore'] <= 0]
print(f"Invalid account rows: {len(invalid_accounts)}")
# Out:
# Invalid account rows: 0

# %%
if len(invalid_accounts) > 0:
    print(invalid_accounts)
else:
    print("valid")
# Out:
# valid

# %%
print(data.isnull().sum())
# Out:
# month                         0
# sip_inflow_crore              0
# active_sip_accounts_crore     0
# new_sip_accounts_lakh         0
# sip_aum_lakh_crore            0
# yoy_growth_pct               12
# dtype: int64

# %%
print("YoY growth range:")
print(f" Min:{data['yoy_growth_pct'].min()}")
print(f" Max:{data['yoy_growth_pct'].max()}")
# Out:
# YoY growth range:
#  Min:15.8
#  Max:53.05

# %%
data.to_csv("C:/Users/vaishnavi/Downloads/Fintech_Capstone_Project/data/processed/clean_sip_inflows.csv", index=False)
print("Saved")
print(data.shape)
# Out:
# Saved
# (48, 6)
