# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/Users/vaishnavi/Downloads/Fintech_Capstone_Project/data/raw/03_aum_by_fund_house.csv")

# %%
print(data.shape)
# Out:
# (90, 5)

# %%
print(data.dtypes)
# Out:
# date               object
# fund_house         object
# aum_lakh_crore    float64
# aum_crore           int64
# num_schemes         int64
# dtype: object

# %%
data.head()
# Out:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
print(data.columns.tolist())
# Out:
# ['date', 'fund_house', 'aum_lakh_crore', 'aum_crore', 'num_schemes']

# %%
data['date'] = pd.to_datetime(data['date'], format='mixed', dayfirst=True)

# %%
print(data['date'].dtype)
# Out:
# datetime64[ns]

# %%
data['date'].head()
# Out:
# 0   2022-03-31
# 1   2022-03-31
# 2   2022-03-31
# 3   2022-03-31
# 4   2022-03-31
# Name: date, dtype: datetime64[ns]

# %%
invalid_aum = data[(data['aum_crore'] <= 0) | (data['aum_lakh_crore'] <= 0)]
print(f"Invalid AUM rows: {len(invalid_aum)}")
# Out:
# Invalid AUM rows: 0

# %%
if len(invalid_aum) > 0:
    print(invalid_aum)
else:
    print("valid")
# Out:
# valid

# %%
print(data.isnull().sum())
# Out:
# date              0
# fund_house        0
# aum_lakh_crore    0
# aum_crore         0
# num_schemes       0
# dtype: int64

# %%
invalid_schemes = data[data['num_schemes'] <= 0]
print(f"Invalid scheme count rows: {len(invalid_schemes)}")
# Out:
# Invalid scheme count rows: 0

# %%
if len(invalid_schemes) > 0:
    print(invalid_schemes)
else:
    print("valid")
# Out:
# valid

# %%
data.to_csv("C:/Users/vaishnavi/Downloads/Fintech_Capstone_Project/data/processed/clean_aum.csv", index=False)
print("Saved")
print(data.shape)
# Out:
# Saved
# (90, 5)
